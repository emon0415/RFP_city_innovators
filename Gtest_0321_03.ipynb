# %%
# !pip install faiss-cpu
# !pip install sentence-transformers
# !pip install tiktoken
# !pip install langchain
# !pip install -U langchain-openai
# !pip install -U langchain-community
# !pip install openpyxl
# Out:
# Requirement already satisfied: faiss-cpu in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (1.10.0)
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy<3.0,>=1.25.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from faiss-cpu) (1.26.2)
# Requirement already satisfied: packaging in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from faiss-cpu) (24.1)
# Requirement already satisfied: sentence-transformers in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (3.4.1)
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (4.49.0)
# Requirement already satisfied: tqdm in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (2.5.1)
# Requirement already satisfied: scikit-learn in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (1.5.2)
# Requirement already satisfied: scipy in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (0.29.0)
# Requirement already satisfied: Pillow in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: filelock in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: networkx in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: sympy==1.13.1 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: numpy>=1.17 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2023.11.17)
# Requirement already satisfied: tiktoken in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (0.9.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from tiktoken) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.26.0->tiktoken) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.26.0->tiktoken) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.26.0->tiktoken) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.26.0->tiktoken) (2023.11.17)
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: langchain in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (0.3.20)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.41 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langchain) (0.3.45)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.6 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langchain) (0.3.6)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langchain) (0.2.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langchain) (2.10.6)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langchain) (2.0.23)
# Requirement already satisfied: requests<3,>=2 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<1.0.0,>=0.3.41->langchain) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<1.0.0,>=0.3.41->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<1.0.0,>=0.3.41->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<1.0.0,>=0.3.41->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchain) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchain) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchain) (2023.11.17)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: anyio in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.6)
# Requirement already satisfied: sniffio in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.41->langchain) (3.0.0)
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: langchain-openai in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (0.3.1)
# Collecting langchain-openai
#   Downloading langchain_openai-0.3.10-py3-none-any.whl.metadata (2.3 kB)
# Collecting langchain-core<1.0.0,>=0.3.48 (from langchain-openai)
#   Downloading langchain_core-0.3.48-py3-none-any.whl.metadata (5.9 kB)
# Collecting openai<2.0.0,>=1.68.2 (from langchain-openai)
#   Downloading openai-1.68.2-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: tiktoken<1,>=0.7 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langchain-openai) (0.9.0)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<1.0.0,>=0.3.48->langchain-openai) (0.2.11)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<1.0.0,>=0.3.48->langchain-openai) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<1.0.0,>=0.3.48->langchain-openai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<1.0.0,>=0.3.48->langchain-openai) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<1.0.0,>=0.3.48->langchain-openai) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<1.0.0,>=0.3.48->langchain-openai) (4.12.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<1.0.0,>=0.3.48->langchain-openai) (2.10.6)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (4.6.2.post1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (0.6.1)
# Requirement already satisfied: sniffio in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (4.66.5)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.32.3)
# Requirement already satisfied: idna>=2.8 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.68.2->langchain-openai) (3.6)
# Requirement already satisfied: certifi in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.68.2->langchain-openai) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.68.2->langchain-openai) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.68.2->langchain-openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.48->langchain-openai) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.48->langchain-openai) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.48->langchain-openai) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<1.0.0,>=0.3.48->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<1.0.0,>=0.3.48->langchain-openai) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.1.0)
# Requirement already satisfied: colorama in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.68.2->langchain-openai) (0.4.6)
# Downloading langchain_openai-0.3.10-py3-none-any.whl (61 kB)
#    ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#    -------------------------- ------------- 41.0/61.2 kB ? eta -:--:--
#    ---------------------------------------- 61.2/61.2 kB 821.8 kB/s eta 0:00:00
# Downloading langchain_core-0.3.48-py3-none-any.whl (418 kB)
#    ---------------------------------------- 0.0/418.7 kB ? eta -:--:--
#    ----- ---------------------------------- 61.4/418.7 kB 1.7 MB/s eta 0:00:01
#    ---------- ----------------------------- 112.6/418.7 kB 1.3 MB/s eta 0:00:01
#    ---------------- ----------------------- 174.1/418.7 kB 1.3 MB/s eta 0:00:01
#    ------------------- -------------------- 204.8/418.7 kB 1.1 MB/s eta 0:00:01
#    -------------------------- ------------- 276.5/418.7 kB 1.3 MB/s eta 0:00:01
#    ------------------------------ --------- 317.4/418.7 kB 1.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 368.6/418.7 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 418.7/418.7 kB 1.1 MB/s eta 0:00:00
# Downloading openai-1.68.2-py3-none-any.whl (606 kB)
#    ---------------------------------------- 0.0/606.1 kB ? eta -:--:--
#    ----- ---------------------------------- 81.9/606.1 kB 2.2 MB/s eta 0:00:01
#    -------- ------------------------------- 122.9/606.1 kB 1.4 MB/s eta 0:00:01
#    ----------- ---------------------------- 174.1/606.1 kB 1.7 MB/s eta 0:00:01
#    -------------- ------------------------- 225.3/606.1 kB 1.3 MB/s eta 0:00:01
#    --------------------- ------------------ 327.7/606.1 kB 1.4 MB/s eta 0:00:01
#    ------------------------ --------------- 368.6/606.1 kB 1.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 450.6/606.1 kB 1.5 MB/s eta 0:00:01
#    ------------------------------- -------- 471.0/606.1 kB 1.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 532.5/606.1 kB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 583.7/606.1 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 606.1/606.1 kB 1.2 MB/s eta 0:00:00
# Installing collected packages: openai, langchain-core, langchain-openai
#   Attempting uninstall: openai
#     Found existing installation: openai 1.63.2
#     Uninstalling openai-1.63.2:
#       Successfully uninstalled openai-1.63.2
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.45
#     Uninstalling langchain-core-0.3.45:
#       Successfully uninstalled langchain-core-0.3.45
#   Attempting uninstall: langchain-openai
#     Found existing installation: langchain-openai 0.3.1
#     Uninstalling langchain-openai-0.3.1:
#       Successfully uninstalled langchain-openai-0.3.1
# Successfully installed langchain-core-0.3.48 langchain-openai-0.3.10 openai-1.68.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# browser-use 0.1.37 requires langchain==0.3.14, but you have langchain 0.3.20 which is incompatible.
# browser-use 0.1.37 requires langchain-openai==0.3.1, but you have langchain-openai 0.3.10 which is incompatible.
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: langchain-community in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (0.3.19)
# Collecting langchain-community
#   Downloading langchain_community-0.3.20-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.45 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (0.3.48)
# Collecting langchain<1.0.0,>=0.3.21 (from langchain-community)
#   Downloading langchain-0.3.21-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (2.0.23)
# Requirement already satisfied: requests<3,>=2 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (3.11.12)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (9.0.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (2.8.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (0.2.11)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: numpy<3,>=1.26.2 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langchain-community) (1.26.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.18.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Collecting langchain-text-splitters<1.0.0,>=0.3.7 (from langchain<1.0.0,>=0.3.21->langchain-community)
#   Downloading langchain_text_splitters-0.3.7-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langchain<1.0.0,>=0.3.21->langchain-community) (2.10.6)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<1.0.0,>=0.3.45->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<1.0.0,>=0.3.45->langchain-community) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<1.0.0,>=0.3.45->langchain-community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchain-community) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchain-community) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchain-community) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchain-community) (2023.11.17)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.1.1)
# Requirement already satisfied: anyio in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.0.6)
# Requirement already satisfied: sniffio in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.45->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.21->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.21->langchain-community) (2.27.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Downloading langchain_community-0.3.20-py3-none-any.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB 100.9 kB/s eta 0:00:25
#    ---------------------------------------- 0.0/2.5 MB 100.9 kB/s eta 0:00:25
#     --------------------------------------- 0.0/2.5 MB 93.7 kB/s eta 0:00:27
#     --------------------------------------- 0.0/2.5 MB 93.7 kB/s eta 0:00:27
#     --------------------------------------- 0.1/2.5 MB 131.3 kB/s eta 0:00:19
#    - -------------------------------------- 0.1/2.5 MB 175.0 kB/s eta 0:00:14
#    - -------------------------------------- 0.1/2.5 MB 204.8 kB/s eta 0:00:12
#    -- ------------------------------------- 0.1/2.5 MB 230.3 kB/s eta 0:00:11
#    -- ------------------------------------- 0.2/2.5 MB 248.0 kB/s eta 0:00:10
#    --- ------------------------------------ 0.2/2.5 MB 288.0 kB/s eta 0:00:09
#    --- ------------------------------------ 0.2/2.5 MB 283.2 kB/s eta 0:00:09
#    --- ------------------------------------ 0.2/2.5 MB 293.0 kB/s eta 0:00:08
#    ---- ----------------------------------- 0.3/2.5 MB 314.7 kB/s eta 0:00:08
#    ---- ----------------------------------- 0.3/2.5 MB 328.0 kB/s eta 0:00:07
#    ----- ---------------------------------- 0.3/2.5 MB 351.1 kB/s eta 0:00:07
#    ----- ---------------------------------- 0.4/2.5 MB 376.1 kB/s eta 0:00:06
#    ------ --------------------------------- 0.4/2.5 MB 402.0 kB/s eta 0:00:06
#    ------ --------------------------------- 0.4/2.5 MB 407.2 kB/s eta 0:00:06
#    ------- -------------------------------- 0.5/2.5 MB 418.0 kB/s eta 0:00:05
#    ------- -------------------------------- 0.5/2.5 MB 427.8 kB/s eta 0:00:05
#    -------- ------------------------------- 0.5/2.5 MB 445.6 kB/s eta 0:00:05
#    --------- ------------------------------ 0.6/2.5 MB 456.4 kB/s eta 0:00:05
#    --------- ------------------------------ 0.6/2.5 MB 477.6 kB/s eta 0:00:04
#    --------- ------------------------------ 0.6/2.5 MB 479.6 kB/s eta 0:00:04
#    ---------- ----------------------------- 0.7/2.5 MB 480.4 kB/s eta 0:00:04
#    ---------- ----------------------------- 0.7/2.5 MB 473.4 kB/s eta 0:00:04
#    ----------- ---------------------------- 0.7/2.5 MB 479.2 kB/s eta 0:00:04
#    ------------ --------------------------- 0.8/2.5 MB 498.3 kB/s eta 0:00:04
#    ------------ --------------------------- 0.8/2.5 MB 503.1 kB/s eta 0:00:04
#    ------------ --------------------------- 0.8/2.5 MB 507.8 kB/s eta 0:00:04
#    ------------ --------------------------- 0.8/2.5 MB 507.8 kB/s eta 0:00:04
#    ------------- -------------------------- 0.9/2.5 MB 508.3 kB/s eta 0:00:04
#    -------------- ------------------------- 0.9/2.5 MB 520.8 kB/s eta 0:00:04
#    --------------- ------------------------ 1.0/2.5 MB 541.3 kB/s eta 0:00:03
#    --------------- ------------------------ 1.0/2.5 MB 542.5 kB/s eta 0:00:03
#    ---------------- ----------------------- 1.1/2.5 MB 567.4 kB/s eta 0:00:03
#    ----------------- ---------------------- 1.1/2.5 MB 570.9 kB/s eta 0:00:03
#    ------------------ --------------------- 1.2/2.5 MB 588.0 kB/s eta 0:00:03
#    ------------------- -------------------- 1.2/2.5 MB 600.0 kB/s eta 0:00:03
#    -------------------- ------------------- 1.3/2.5 MB 625.7 kB/s eta 0:00:02
#    --------------------- ------------------ 1.4/2.5 MB 640.9 kB/s eta 0:00:02
#    ---------------------- ----------------- 1.4/2.5 MB 664.9 kB/s eta 0:00:02
#    ----------------------- ---------------- 1.5/2.5 MB 678.6 kB/s eta 0:00:02
#    ------------------------ --------------- 1.6/2.5 MB 696.3 kB/s eta 0:00:02
#    -------------------------- ------------- 1.7/2.5 MB 717.7 kB/s eta 0:00:02
#    -------------------------- ------------- 1.7/2.5 MB 711.9 kB/s eta 0:00:02
#    ---------------------------- ----------- 1.8/2.5 MB 732.0 kB/s eta 0:00:02
#    ---------------------------- ----------- 1.8/2.5 MB 735.7 kB/s eta 0:00:01
#    ----------------------------- ---------- 1.8/2.5 MB 733.2 kB/s eta 0:00:01
#    ------------------------------ --------- 1.9/2.5 MB 743.8 kB/s eta 0:00:01
#    ------------------------------ --------- 2.0/2.5 MB 754.7 kB/s eta 0:00:01
#    ------------------------------- -------- 2.0/2.5 MB 754.3 kB/s eta 0:00:01
#    -------------------------------- ------- 2.0/2.5 MB 758.8 kB/s eta 0:00:01
#    -------------------------------- ------- 2.0/2.5 MB 758.8 kB/s eta 0:00:01
#    --------------------------------- ------ 2.1/2.5 MB 755.5 kB/s eta 0:00:01
#    --------------------------------- ------ 2.1/2.5 MB 755.5 kB/s eta 0:00:01
#    --------------------------------- ------ 2.1/2.5 MB 755.5 kB/s eta 0:00:01
#    --------------------------------- ------ 2.1/2.5 MB 755.5 kB/s eta 0:00:01
#    --------------------------------- ------ 2.1/2.5 MB 755.5 kB/s eta 0:00:01
#    ---------------------------------- ----- 2.2/2.5 MB 723.4 kB/s eta 0:00:01
#    ----------------------------------- ---- 2.2/2.5 MB 726.4 kB/s eta 0:00:01
#    ----------------------------------- ---- 2.2/2.5 MB 721.7 kB/s eta 0:00:01
#    ------------------------------------- -- 2.3/2.5 MB 739.8 kB/s eta 0:00:01
#    ------------------------------------- -- 2.4/2.5 MB 746.3 kB/s eta 0:00:01
#    ------------------------------------- -- 2.4/2.5 MB 746.3 kB/s eta 0:00:01
#    ------------------------------------- -- 2.4/2.5 MB 717.5 kB/s eta 0:00:01
#    -------------------------------------- - 2.4/2.5 MB 726.2 kB/s eta 0:00:01
#    ---------------------------------------  2.5/2.5 MB 743.3 kB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 734.7 kB/s eta 0:00:00
# Downloading langchain-0.3.21-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    - -------------------------------------- 0.0/1.0 MB 1.3 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.1/1.0 MB 1.7 MB/s eta 0:00:01
#    -------- ------------------------------- 0.2/1.0 MB 1.7 MB/s eta 0:00:01
#    -------------- ------------------------- 0.4/1.0 MB 1.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.4/1.0 MB 1.8 MB/s eta 0:00:01
#    --------------------- ------------------ 0.6/1.0 MB 1.9 MB/s eta 0:00:01
#    ------------------------- -------------- 0.6/1.0 MB 1.9 MB/s eta 0:00:01
#    ------------------------------ --------- 0.8/1.0 MB 2.0 MB/s eta 0:00:01
#    ------------------------------- -------- 0.8/1.0 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------ --- 0.9/1.0 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------  1.0/1.0 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 1.9 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.3.7-py3-none-any.whl (32 kB)
# Installing collected packages: langchain-text-splitters, langchain, langchain-community
#   Attempting uninstall: langchain-text-splitters
#     Found existing installation: langchain-text-splitters 0.3.6
#     Uninstalling langchain-text-splitters-0.3.6:
#       Successfully uninstalled langchain-text-splitters-0.3.6
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.20
#     Uninstalling langchain-0.3.20:
#       Successfully uninstalled langchain-0.3.20
#   Attempting uninstall: langchain-community
#     Found existing installation: langchain-community 0.3.19
#     Uninstalling langchain-community-0.3.19:
#       Successfully uninstalled langchain-community-0.3.19
# Successfully installed langchain-0.3.21 langchain-community-0.3.20 langchain-text-splitters-0.3.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# browser-use 0.1.37 requires langchain==0.3.14, but you have langchain 0.3.21 which is incompatible.
# browser-use 0.1.37 requires langchain-openai==0.3.1, but you have langchain-openai 0.3.10 which is incompatible.
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: openpyxl in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\堀江雅彦\appdata\local\programs\python\python311\lib\site-packages (from openpyxl) (2.0.0)
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import pandas as pd
import requests
from dotenv import load_dotenv

# LangChain 関連
from langchain.chains import RetrievalQA
from langchain.chat_models import AzureChatOpenAI
from langchain_openai import AzureOpenAIEmbeddings
from langchain_community.vectorstores import FAISS
from langchain.prompts import PromptTemplate
from langchain.docstore.document import Document
from langchain.schema import Document

# GraphRAG用
import torch
from transformers import RagTokenizer, RagRetriever, RagSequenceForGeneration
import networkx as nx

# %%
# .env ファイルを読み込む
load_dotenv()
# Out:
# True

# %%
# 1. データの読み込み
df = pd.read_excel("100データ5.xlsx", engine="openpyxl")
df.head()
# Out:
#    id   date             timestamp    place  latitude  longitude  \
# 0   1  18278  1950-01-15T10:30:00Z  大阪市住吉区    34.5938   135.4937
# 1   2  18709  1951-03-22T15:45:00Z  大阪市住吉区    34.5938   135.4937
# 2   3  19124  1952-05-10T09:15:00Z  大阪市住吉区    34.5938   135.4937
# 3   4  19565  1953-07-25T16:20:00Z  大阪市住吉区    34.5938   135.4937
# 4   5  19972  1954-09-05T14:40:00Z  大阪市住吉区    34.5938   135.4937
#
#                 lat_long                                         diary_text
# 0  34.5938° N, 135.4937°  父の数学の参考書を読みながら、将来の夢について考えた。野球への情熱が日に日に強くなっていく。...
# 1  34.5938° N, 135.4937°  今日の野球の練習は厳しかったが、チームメイトと共に汗を流すことで絆が深まった。夕方は家族と一...
# 2  34.5938° N, 135.4937°  今朝、父と一緒に野球の戦術について語り合った。数学的思考が野球にも活かせると感じた。夕方は近...
# 3  34.5938° N, 135.4937°  夏の甲子園予選に向けて、猛暑の中で練習に励んでいる。汗と熱意で、チームの勝利を信じている。夜...
# 4  34.5938° N, 135.4937°  高校野球の最後の大会。悔いなく全力で戦った。負けは悔しいが、チームメイトとの絆は一生の宝物と...

# %%
API_KEY = os.getenv("GOOGLE_MAPS_API_KEY")  # 直接記述する場合は "your-api-key" に変更

# 緯度・経度から住所を取得し、国内・海外で異なるフォーマットに整形
def get_formatted_location(latitude, longitude):
    url = f"https://maps.googleapis.com/maps/api/geocode/json?latlng={latitude},{longitude}&key={API_KEY}&language=ja"
    response = requests.get(url)
    data = response.json()
    
    if "results" in data and len(data["results"]) > 0:
        address_components = data["results"][0]["address_components"]
        
        country = ""
        prefecture = ""
        city = ""

        for component in address_components:
            if "country" in component["types"]:
                country = component["long_name"]  # 日本 or France
            elif "administrative_area_level_1" in component["types"]:
                prefecture = component["long_name"]  # 東京都, 大阪府
            elif "locality" in component["types"] or "administrative_area_level_2" in component["types"]:
                city = component["long_name"]  # 新宿区, 横浜市

        # 国内なら「東京都 新宿区」、海外なら「フランス Paris」に変換
        if country == "日本":
            return f"{prefecture} {city}".replace("都", "").replace("府", "").replace("県", "")  # 「東京都 新宿区」→「東京 新宿」
        else:
            return f"{country} {city}"

    return "住所情報が取得できませんでした"

# Excelファイルの読み込み
df = pd.read_excel("100データ5.xlsx", engine="openpyxl")

# location_name列を追加（緯度・経度を使って変換）
df["location"] = df.apply(lambda row: get_formatted_location(row["latitude"], row["longitude"]), axis=1)

# %%
documents = []
for idx, row in df.iterrows():
    text_content = f"""日記ID: {row['id']}
日時: {row['timestamp']}
場所: {row['location']}
本文: {row['diary_text']}
画像: {row.get('image_path', '画像パスなし')}"""

    documents.append(Document(
        page_content=text_content,
        metadata={"id": row["id"]}
    ))

# %%
documents
# Out:
# [Document(metadata={'id': 1}, page_content='日記ID: 1\n日時: 1950-01-15T10:30:00Z\n場所: 住所情報が取得できませんでした\n本文: 父の数学の参考書を読みながら、将来の夢について考えた。野球への情熱が日に日に強くなっていく。レフトの守備練習に励み、甲子園を目指す決意を新たにした。\n画像: 画像パスなし'),
#  Document(metadata={'id': 2}, page_content='日記ID: 2\n日時: 1951-03-22T15:45:00Z\n場所: 住所情報が取得できませんでした\n本文: 今日の野球の練習は厳しかったが、チームメイトと共に汗を流すことで絆が深まった。夕方は家族と一緒に夕食を楽しんだ。将来への希望に胸を膨らませている。\n画像: 画像パスなし'),
#  Document(metadata={'id': 3}, page_content='日記ID: 3\n日時: 1952-05-10T09:15:00Z\n場所: 住所情報が取得できませんでした\n本文: 今朝、父と一緒に野球の戦術について語り合った。数学的思考が野球にも活かせると感じた。夕方は近所の友人とキャッチボールを楽しんだ。\n画像: 画像パスなし'),
#  Document(metadata={'id': 4}, page_content='日記ID: 4\n日時: 1953-07-25T16:20:00Z\n場所: 住所情報が取得できませんでした\n本文: 夏の甲子園予選に向けて、猛暑の中で練習に励んでいる。汗と熱意で、チームの勝利を信じている。夜は冷たい麦茶で喉を潤した。\n画像: 画像パスなし'),
#  Document(metadata={'id': 5}, page_content='日記ID: 5\n日時: 1954-09-05T14:40:00Z\n場所: 住所情報が取得できませんでした\n本文: 高校野球の最後の大会。悔いなく全力で戦った。負けは悔しいが、チームメイトとの絆は一生の宝物となった。夕方、父から励ましの言葉をもらった。\n画像: 画像パスなし'),
#  Document(metadata={'id': 6}, page_content='日記ID: 6\n日時: 1955-12-18T11:55:00Z\n場所: 住所情報が取得できませんでした\n本文: 大学受験勉強に没頭している。野球への情熱を学業にも注ぎ込みたい。母の手料理が勉強の活力となっている。将来の夢を描きながら、静かな日曜日を過ごす。\n画像: 画像パスなし'),
#  Document(metadata={'id': 7}, page_content='日記ID: 7\n日時: 1956-02-14T13:30:00Z\n場所: 住所情報が取得できませんでした\n本文:
45:00Z\n場所: 住所情報が取得できませんでした\n本文: 阪神タイガースの試合観戦。相変わらずの熱い応援。甲子園の雰囲気に包まれ、青春時代の思い出が蘇る。サザエと一緒に声援を送る。\n画像: 画像パスなし'),
#  Document(metadata={'id': 50}, page_content='日記ID: 50\n日時: 1987-11-03T20:00:00Z\n場所: 住所情報が取得できませんでした\n本文: 穴子アナスケとの恒例の飲み会。仕事の苦労話や家族の近況を語り合う。長年の友情を感じながら、人生の喜びを分かち合う。\n画像: 画像パスなし'),
#  Document(metadata={'id': 51}, page_content='日記ID: 51\n日時: 1987-12-25T16:55:00Z\n場所: 住所情報が取得できませんでした\n本文: タラオの双子の子供に初めて会う。祖父としての喜びと愛おしさに満ちた日。\n画像: 画像パスなし'),
#  Document(metadata={'id': 52}, page_content='日記ID: 52\n日時: 1988-05-05T15:20:00Z\n場所: 住所情報が取得できませんでした\n本文: タラオの双子の子供の成長に喜びを感じる。双子だから当たり前だが、よく似ている。\n画像: 画像パスなし'),
#  Document(metadata={'id': 53}, page_content='日記ID: 53\n日時: 1988-07-18T19:30:00Z\n場所: 住所情報が取得できませんでした\n本文: 穴子アナスケとの恒例の飲み会。年を重ねても変わらない友情に感謝。人生の喜びを分かち合う。\n画像: 画像パスなし'),
#  Document(metadata={'id': 54}, page_content='日記ID: 54\n日時: 1989-02-14T11:40:00Z\n場所: 住所情報が取得できませんでした\n本文: サザエとの些細な喧嘩。数日間口をきかないが、深い愛情は変わらない。夫婦の絆を改めて感じる静かな午後。\n画像: 画像パスなし'),
#  Document(metadata={'id': 55}, page_content='日記ID: 55\n日時: 1989-03-30T10:05:00Z\n場所: 住所情報が取得できませんでした\n本文: 用務員を定年退職。学校での思い出を胸に、新たな人生の章を迎える。\n画像: 画像パスなし'),
#  Document(metadata={'id': 56}, page_content='日記ID: 56\n日時: 1990-06-12T15:40:00Z\n場所: 住所情報が取得できませんでした\n本文: 家族と過ごす時間が増えた。孫たちの成長を見守り、人生の喜びを感じている。retirement後の充実した日々。\n画像: 画像パスなし'),
#  Document(metadata={'id': 57}, page_content='日記ID: 57\n日時: 1990-07-07T16:30:00Z\n場所: 住所情報が取得できませんでした\n本文: 奄美大島を初めて訪れ、息子の新たな人生の始まりを感じる。島の美しい景色と息子の夢に感動。\n画像: 画像パスなし'),
#  Document(metadata={'id': 58}, page_content='日記ID: 58\n日時: 1991-09-23T14:15:00Z\n場所: 住所情報が取得できませんでした\n本文: タラオの家族を訪問。奄美大島の焼酎を堪能し、家族との絆を深める。島の美しい景色に癒される。\n画像: 画像パスなし'),
#  Document(metadata={'id': 59}, page_content='日記ID: 59\n日時: 1991-09-23T19:45:00Z\n場所: 住所情報が取得できませんでした\n本文: 穴子アナスケとの飲み会。キャリアの後半を語り合い、互いの人生を振り返る。長年の友情と仕事への誇りを感じる夜。\n画像: 画像パスなし'),
#  Document(metadata={'id': 61}, page_content='日記ID: 61\n日時: 1992-02-14T11:30:00Z\n場所: 住所情報が取得できませんでした\n本文: 妻サザエとの恒例の些細な喧嘩。長年連れ添った夫婦の絆を改めて感じる温かな時間。\n画像: 画像パスなし'),
#  Document(metadata={'id': 60}, page_content='日記ID: 60\n日時: 1992-12-25T14:15:00Z\n場所: 住所情報が取得できませんでした\n本文: クリスマスを家族と過ごす。タラオの成長と、サザエの温かさに感謝。定年を間近に控え、家族との時間の大切さを痛感する。\n画像: 画像パスなし'),
#  Document(metadata={'id': 62}, page_content='日記ID: 62\n日時: 1993-03-20T11:30:00Z\n場所: 住所情報が取得できませんでした\n本文: 定年退職を前に、海山商事での思い出を振り返る。仕事への情熱と、築いてきたキャリアに誇りを感じる。家族の支えに感謝。\n画像: 画像パスなし'),
#  Document(metadata={'id': 63}, page_content='日記ID: 63\n日時: 1993-07-07T20:00:00Z\n場所: 住所情報が取得できませんでした\n本文: 穴子アナスケとの飲み
00Z\n場所: 住所情報が取得できませんでした\n本文: タラオの家族と共に過ごす春の島。家族の絆と愛情を深く感じる特別な時間。\n画像: 画像パスなし'),
#  Document(metadata={'id': 92}, page_content='日記ID: 92\n日時: 2019-06-30T15:40:00Z\n場所: 住所情報が取得できませんでした\n本文: カツオとわかめの家族と共に過ごす夏の午後。波平の昔話に孫たちが魅了される。家族の温かさと伝統を感じる。\n画像: 画像パスなし'),
#  Document(metadata={'id': 93}, page_content='日記ID: 93\n日時: 2020-01-01T10:30:00Z\n場所: 住所情報が取得できませんでした\n本文: 新年の家族団らん。波平とふねの健康を祈り、カツオとわかめの家族と共に過ごす。孫たちの成長に驚き、家族の絆の温かさを感じる。\n画像: 画像パスなし'),
#  Document(metadata={'id': 94}, page_content='日記ID: 94\n日時: 2021-05-05T14:15:00Z\n場所: 住所情報が取得できませんでした\n本文: タラオの家族とオンライン通話。やっぱり、タラオ家族に会いたくなる。\n画像: 画像パスなし'),
#  Document(metadata={'id': 95}, page_content='日記ID: 95\n日時: 2022-08-22T19:40:00Z\n場所: 住所情報が取得できませんでした\n本文: 穴子アナスケとの恒例の飲み会。波平から聞いた昔話を共有し、笑い合う。家族の思い出と友情の素晴らしさを感じる夜。\n画像: 画像パスなし'),
#  Document(metadata={'id': 96}, page_content='日記ID: 96\n日時: 2023-11-03T15:50:00Z\n場所: 住所情報が取得できませんでした\n本文: わかめの子供たちが遊びに来る。にぎやかな家族団らん。波平とふねも孫たちと楽しく過ごす。家族の温かさに包まれる。\n画像: 画像パスなし'),
#  Document(metadata={'id': 97}, page_content='日記ID: 97\n日時: 2024-02-14T13:30:00Z\n場所: 住所情報が取得できませんでした\n本文: カツオと一緒にタラオの家族を訪問。島の焼酎を楽しみながら、家族の絆を深める。三世代の思い出を作る。\n画像: 画像パスなし'),
#  Document(metadata={'id': 98}, page_content='日記ID: 98\n日時: 2024-07-07T16:20:00Z\n場所: 住所情報が取得できませんでした\n本文: サザエと静かな夏の午後。長年連れ添った夫婦の絆を感じる。波平とふねの健康を祈り、家族の温かさを噛みしめる。\n画像: 画像パスなし'),
#  Document(metadata={'id': 99}, page_content='日記ID: 99\n日時: 2025-01-15T10:40:00Z\n場所: 住所情報が取得できませんでした\n本文: 体調不良を感じながらも、家族への感謝と愛情を込めて日記を綴る。波平、ふね、カツオ、わかめ、サザエ、タラオへの深い愛情を感じる。\n画像: 画像パスなし'),
#  Document(metadata={'id': 100}, page_content='日記ID: 100\n日時: 2025-02-03T15:30:00Z\n場所: 住所情報が取得できませんでした\n本文: 最後の日記。家族への感謝と愛を込めて、静かに人生の幕を閉じる。\n画像: 画像パスなし')]

# %%
# 2. 埋め込みモデルを設定
# --- (b) Azure OpenAI Embeddingsを使う場合 ---
embedding_model = AzureOpenAIEmbeddings(
    deployment="text-embedding-3-large",  # ✅ ← 正しくは deployment=
    azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
    api_key=os.getenv("AZURE_OPENAI_API_KEY"),
    api_version="2023-05-15",
    chunk_size=1
)

# %%
# --- (b) Azure OpenAI Embeddingsを使う場合 ---

# FAISSベクトルストアを構築
#  - from_documents() で一度にDocumentリストをEmbeddingし、インデックスを構築
faiss_db = FAISS.from_documents(documents, embedding_model)

# =====================================
# 3) RetrievalQA チェーン構築
# =====================================
# Azure OpenAI を LangChain の llm として定義
chat_llm = AzureChatOpenAI(
    azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"), 
    openai_api_key=os.getenv("AZURE_OPENAI_API_KEY"),
    openai_api_version=os.getenv("AZURE_OPENAI_API_VERSION"),
    deployment_name="gpt-4o-mini",  # Azure でデプロイしたモデル名
    temperature=0.7
)

# RetrievalQAを作成
retrieval_qa = RetrievalQA.from_chain_type(
    llm=chat_llm,
    chain_type="stuff",  # 単純に検索結果ドキュメントを結合する方式
    retriever=faiss_db.as_retriever(search_kwargs={"k": 3})
)
# Out:
# C:\Users\堀江雅彦\AppData\Local\Temp\ipykernel_16496\4052380232.py:11: LangChainDeprecationWarning: The class `AzureChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import AzureChatOpenAI``.
#   chat_llm = AzureChatOpenAI(

# %%
# 家族構成の定義
calling_name1="僕"
calling_name2="タラちゃん"
calling_name3="ママ"
relation_name1="本人"
relation_name2="息子"
relation_name3="妻"
birthday_name1="1940-07-21"
birthday_name2="1970-05-24"
birthday_name3="1970-10-18"

# %%
# --- (b) Azure OpenAI Embeddingsを使う場合 ---

# =====================================
# 4) デモ用の質問 + 類似スコア付き検索
# =====================================
question = "誕生日の思い出は？"

# スコア付きで検索（類似度が高いほどスコアは小さい）
retriever = faiss_db.as_retriever(search_kwargs={"k": 3})
docs_and_scores = retriever.vectorstore.similarity_search_with_score(question, k=3)

# %%
# 検索結果の表示
print("▼ 検索でヒットした日記とスコア（スコアが小さいほど類似）:")
for i, (doc, score) in enumerate(docs_and_scores):
    print(f"\n--- Top {i+1} ---")
    print(f"スコア: {score:.4f}")
    print(doc.page_content)  # 長いので最初だけ表示

# ヒットしたドキュメントを連結して、プロンプトとして LLM に渡す
context = "\n---\n".join([doc.page_content for doc, _ in docs_and_scores])

# 親として振る舞うよう明示したプロンプト
final_prompt = PromptTemplate.from_template(
    """
    あなたは天国にいて子供を見守っています。
    あなたに語りかけるあなたの子供のコメント{question}に対して、
    家族の素晴らしい思い出を一緒に回想してコメントを作成してください。
    全てのコメントは親子間のフランクな口調で、優しく語りかけるような表現にしてください。
    あなたが残した日記のコメントは下記3件あります。{context}
    日記の内容を含めて回想してください。
    ただし、子供のコメントに対して、ロケーション・場所・年月日が大きく異なる日記の内容は回想に含める必要はありません。
    なお、あなたの家族構成と呼称を伝えます。{relation_name1}のことを{calling_name1}、
    {relation_name2}のことを{calling_name2}、{relation_name3}のことを{calling_name3}と呼んでください。
    あなたの家族の誕生日は、{relation_name1}は{birthday_name1}、{relation_name2}は{birthday_name2}、
    {relation_name3}は{birthday_name3}となります。こちらも文脈に合えば使ってください。
    200文字以内にしてください。
    """
).partial(
    calling_name1=calling_name1,
    calling_name2=calling_name2,
    calling_name3=calling_name3,
    relation_name1=relation_name1,
    relation_name2=relation_name2,
    relation_name3=relation_name3,
    birthday_name1=birthday_name1,
    birthday_name2=birthday_name2,
    birthday_name3=birthday_name3
)

final_prompt_text = final_prompt.format(
    question=question,
    context=context
)

# LLM に直接問い合わせ
response = chat_llm.invoke(final_prompt_text)

print("\n▼User:")
print(question)
print("▼Assistant (Parent):")
print(response.content)
# Out:
# ▼ 検索でヒットした日記とスコア（スコアが小さいほど類似）:
#
# --- Top 1 ---
# スコア: 0.8810
# 日記ID: 7
# 日時: 1991-03-20T14:11:33Z
# 場所: 東京 墨田区
# 本文: 娘の誕生日。手作りのケーキと手紙。妻と二人で、娘の成長と愛情に感動。家族の温かさを感じる特別な日。
# 画像: 画像パスなし
#
# --- Top 2 ---
# スコア: 1.1120
# 日記ID: 22
# 日時: 2000-02-14T11:33:44Z
# 場所: 東京 墨田区
# 本文: 娘が初めて手作りのバレンタインチョコレート。少し歪な形だけど、愛情たっぷりの一品。妻と目を合わせ、娘の成長に静かに感動する。
# 画像: 画像パスなし
#
# --- Top 3 ---
# スコア: 1.1245
# 日記ID: 38
# 日時: 2007-02-14T11:33:22Z
# 場所: 東京 新宿区
# 本文: バレンタインデー。娘が手作りのチョコレートと手紙。妻と二人で、娘の成長と愛情に感動。家族の温かさを感じる特別な日。
# 画像: 画像パスなし
#
# ▼User:
# 誕生日の思い出は？
# ▼Assistant (Parent):
# ああ、タラちゃん、君が小さかった頃の誕生日を思い出すよ。1991年の娘の誕生日、僕とママが手作りのケーキを用意して、君の成長を見守りながら感動したね。あの温かい家族の雰囲気、今でも忘れられないよ。君の笑顔が、僕たちの宝物なんだ。これからも、その笑顔を大切にしてね。

# %% [markdown]
# 以下はGraphRAGの作成

# %%
class GraphRAG:
    def __init__(self, rag_model_name='facebook/rag-sequence-nq', graph_data=None):
        # RAGモデル用のトークナイザーをロード
        self.tokenizer = RagTokenizer.from_pretrained(rag_model_name)
        # RAGのリトリーバー(ドキュメントを検索)をロード
        self.retriever = RagRetriever.from_pretrained(rag_model_name, index_name="custom", passages_path=None)
        # テキストを生成するRAGモデルをロード
        self.model = RagSequenceForGeneration.from_pretrained(rag_model_name)
        
        # グラフデータを用意（例：ノード情報とエッジを定義）graph_dataが渡されればそれを使用し、なければ空のグラフを作成
        self.graph = graph_data or nx.Graph()

    def add_node(self, node_id, node_data):
        self.graph.add_node(node_id, data=node_data)
    
    def add_edge(self, node_id1, node_id2, edge_data):
        self.graph.add_edge(node_id1, node_id2, data=edge_data)
    
    def search_graph(self, query):
        # グラフ内で情報を検索するロジック（例：ノードの関連情報を抽出）
        nodes = list(self.graph.nodes(data=True))
        return [node for node in nodes if query.lower() in node[1]['data'].lower()]
    
    def generate_with_graph(self, input_text):
        # グラフ検索を行い、関連する情報を取得
        relevant_nodes = self.search_graph(input_text)
        context = ' '.join([node[1]['data'] for node in relevant_nodes])
        
        # RAGで情報生成
        inputs = self.tokenizer(input_text, return_tensors="pt")
        retrieved_docs = self.retriever(input_ids=inputs["input_ids"], context=context, n_docs=5)
        generated_ids = self.model.generate(input_ids=inputs["input_ids"], retrieved_doc_ids=retrieved_docs['doc_ids'])
        
        return self.tokenizer.decode(generated_ids[0], skip_special_tokens=True)

# GraphRAGの使用例
graph_data = nx.Graph()
graph_data.add_node(1, data="AI technology in healthcare")
graph_data.add_node(2, data="Recent advancements in NLP")
graph_data.add_edge(1, 2, data="AI and NLP are closely related in healthcare.")

graph_rag = GraphRAG(graph_data=graph_data)
input_query = "Tell me about AI in healthcare"
output = graph_rag.generate_with_graph(input_query)
print(output)
